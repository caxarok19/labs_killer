# %%
from math import exp
import matplotlib.pyplot as plt
import numpy as np

x = []
y = []
x1 = []
y1 = []
x2 = []
y2 = []
e = 2.22*10**(-16)
with open('data2.txt', 'r') as f1:
    data1 = f1.readlines()
for row in data1:
    x1.append(float(row.split()[0]))
    y1.append(float(row.split()[1]))
# with open('data2.txt', 'r') as f2:
#     data2 = f2.readlines()
# for row in data2:
#     x2.append(float(row.split()[0]))
#     y2.append(float(row.split()[1]))
x1 = np.log(x1)
y1 = np.log(y1)
# x2 = np.log(x2)
# y2 = np.log(y2)
#x = np.linspace(0, 10, 1000)
#y = np.exp(x)
coefs = np.polyfit(x1[7360:8000], y1[7360:8000], 1)
print(coefs[0], coefs[1])
p = np.poly1d(coefs)
#x= np.linspace(x1.min(), x1.max(), 500)
y = p(x1[7360:8000])
#plt.plot(x1[7360:8000], y, label='polynom')
plt.plot(x1, y1, label = "data", color = 'r')
# plt.plot(x2, y2, label='N = 5')
#plt.plot(x, y, label = 'polynom')
plt.legend()
plt.grid()
plt.xlabel("Число подотрезков")
plt.ylabel('Ошибка интегрирования')
plt.title("N = 2")
plt.savefig('data2.png')
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_39556/1606343833.py:22: RuntimeWarning: invalid value encountered in log
#   x1 = np.log(x1)
# C:\Users\PC\AppData\Local\Temp/ipykernel_39556/1606343833.py:23: RuntimeWarning: divide by zero encountered in log
#   y1 = np.log(y1)
# 2.46735800024169 -4.232543188234327

# %%
from math import exp
import matplotlib.pyplot as plt
import numpy as np

x = []
y = []
x1 = []
y1 = []
x2 = []
y2 = []
e = 2.22*10**(-16)
with open('data2_RR.txt', 'r') as f1:
    data1 = f1.readlines()
for row in data1:
    x1.append(float(row.split()[0]))
    y1.append(float(row.split()[1]))
# with open('data2.txt', 'r') as f2:
#     data2 = f2.readlines()
# for row in data2:
#     x2.append(float(row.split()[0]))
#     y2.append(float(row.split()[1]))
#x1 = np.log(x1)
y1 = np.log(y1)
# x2 = np.log(x2)
# y2 = np.log(y2)
#x = np.linspace(0, 10, 1000)
#y = np.exp(x)
coefs = np.polyfit(x1[7360:8000], y1[7360:8000], 1)
print(coefs[0], coefs[1])
p = np.poly1d(coefs)
#x= np.linspace(x1.min(), x1.max(), 500)
y = p(x1[7360:8000])
#plt.plot(x1[7360:8000], y, label='polynom')
plt.plot(x1, y1, label = "data" , color = 'r')
# plt.plot(x2, y2, label='N = 5')
#plt.plot(x, y, label = 'polynom')
plt.legend()
plt.grid()
plt.xlabel("Число подотрезков")
plt.ylabel('Ошибка интегрирования')
plt.title("N = 2(Ричардсон)")
plt.savefig('data2_1.png')
# Out:
# 1.167474983343326e-15 -22.814975151586562

# %%
from math import exp
import matplotlib.pyplot as plt
import numpy as np

x = []
y = []
x1 = []
y1 = []
x2 = []
y2 = []
e = 2.22*10**(-16)
with open('data5.txt', 'r') as f1:
    data1 = f1.readlines()
for row in data1:
    x1.append(float(row.split()[0]))
    y1.append(float(row.split()[1]))
# with open('data2.txt', 'r') as f2:
#     data2 = f2.readlines()
# for row in data2:
#     x2.append(float(row.split()[0]))
#     y2.append(float(row.split()[1]))
x1 = np.log(x1)
y1 = np.log(y1)
# x2 = np.log(x2)
# y2 = np.log(y2)
#x = np.linspace(0, 10, 1000)
#y = np.exp(x)
coefs = np.polyfit(x1[7360:8000], y1[7360:8000], 1)
print(coefs[0], coefs[1])
p = np.poly1d(coefs)
#x= np.linspace(x1.min(), x1.max(), 500)
y = p(x1[7360:8000])
#plt.plot(x1[7360:8000], y, label='polynom')
plt.plot(x1, y1, label = "data", color = 'g')
# plt.plot(x2, y2, label='N = 5')
#plt.plot(x, y, label = 'polynom')
plt.legend()
plt.grid()
plt.xlabel("Число подотрезков")
plt.ylabel('Ошибка интегрирования')
plt.title("N = 5")
plt.savefig('data5.png')
# Out:
# C:\Users\PC\AppData\Local\Temp/ipykernel_39556/1018884928.py:22: RuntimeWarning: invalid value encountered in log
#   x1 = np.log(x1)
# 4.204773602603509 -19.591568673650237

# %%
from math import exp
import matplotlib.pyplot as plt
import numpy as np

x = []
y = []
x1 = []
y1 = []
x2 = []
y2 = []
e = 2.22*10**(-16)
with open('data5_RR.txt', 'r') as f1:
    data1 = f1.readlines()
for row in data1:
    x1.append(float(row.split()[0]))
    y1.append(float(row.split()[1]))
# with open('data2.txt', 'r') as f2:
#     data2 = f2.readlines()
# for row in data2:
#     x2.append(float(row.split()[0]))
#     y2.append(float(row.split()[1]))
#x1 = np.log(x1)
y1 = np.log(y1)
# x2 = np.log(x2)
# y2 = np.log(y2)
#x = np.linspace(0, 10, 1000)
#y = np.exp(x)
coefs = np.polyfit(x1[7360:8000], y1[7360:8000], 1)
print(coefs[0], coefs[1])
p = np.poly1d(coefs)
#x= np.linspace(x1.min(), x1.max(), 500)
y = p(x1[7360:8000])
#plt.plot(x1[7360:8000], y, label='polynom')
plt.plot(x1, y1, label = "data" , color = 'g')
# plt.plot(x2, y2, label='N = 5')
#plt.plot(x, y, label = 'polynom')
plt.legend()
plt.grid()
plt.xlabel("Число подотрезков")
plt.ylabel('Ошибка интегрирования')
plt.title("N = 5(Ричардсон)")
plt.savefig('data5_1.png')
# Out:
# 1.5566333111244348e-15 -23.10967471227055
